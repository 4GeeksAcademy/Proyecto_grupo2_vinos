# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\\Users\\Pauline\\Downloads\\Proyecto_grupo2_vinos\\tintos\\FINAL_DF_TINTOS.csv') 
df.T.head
# Out:
# <bound method NDFrame.head of                                                                   0      \
# Url                   https://www.vivino.com/ES/es/crealto-pionda/w/...
# ID                                                              3105259
# Nombre                                                           Pionda
# Año                                                                2018
# País                                                             Italia
# Región                                                       Monferrato
# Bodega                                                          Crealto
# Tipo de vino                                                 Vino tinto
# Uva                                                            Nebbiolo
# Precio                                                            32.53
# Valoración                                                          3.8
# Contenido de alcohol                                                  5
# ...
